# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
hr_df = pd.read_csv('/content/drive/MyDrive/머신러닝 프로젝트/data/hr.csv')

# %%
hr_df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  awards_won?  avg_training_score  is_promoted
# 0                  8            0                  49            0
# ...

# %%
hr_df.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'awards_won?', 'avg_training_score',
#        'is_promoted'],
#       dtype='object')

# %% [markdown]
# * employee_id - 직원 ID
# * department - 부서
# * region - 지역
# * education - 학력
# * gender - 성별
# * recruitment_channel - 채용 경로
# * no_of_trainings - 교육 횟수
# * age - 나이
# * previous_year_rating - 전년도 평가
# * length_of_service - 근속 연수
# * awards_won? - 수상 여부
# * avg_training_score - 평균 교육 점수
# * is_promoted - 승진 여부

# %%
hr_df.drop('employee_id', axis = 1, inplace=True)

# %%
hr_df.describe()
# Out:
#        no_of_trainings           age  previous_year_rating  length_of_service  \
# count     54808.000000  54808.000000          50684.000000       54808.000000
# mean          1.253011     34.803915              3.329256           5.865512
# std           0.609264      7.660169              1.259993           4.265094
# min           1.000000     20.000000              1.000000           1.000000
# 25%           1.000000     29.000000              3.000000           3.000000
# 50%           1.000000     33.000000              3.000000           5.000000
# 75%           1.000000     39.000000              4.000000           7.000000
# max          10.000000     60.000000              5.000000          37.000000
#
#         awards_won?  avg_training_score   is_promoted
# count  54808.000000        54808.000000  54808.000000
# mean       0.023172           63.386750      0.085170
# std        0.150450           13.371559      0.279137
# ...

# %%
hr_df.describe(include='all')
# Out:
#                department    region   education gender recruitment_channel  \
# count               54808     54808       52399  54808               54808
# unique                  9        34           3      2                   3
# top     Sales & Marketing  region_2  Bachelor's      m               other
# freq                16840     12343       36669  38496               30446
# mean                  NaN       NaN         NaN    NaN                 NaN
# std                   NaN       NaN         NaN    NaN                 NaN
# min                   NaN       NaN         NaN    NaN                 NaN
# 25%                   NaN       NaN         NaN    NaN                 NaN
# 50%                   NaN       NaN         NaN    NaN                 NaN
# 75%                   NaN       NaN         NaN    NaN                 NaN
# max                   NaN       NaN         NaN    NaN                 NaN
#
#         no_of_trainings           age  previous_year_rating  \
# ...

# %%
hr_df['education'].value_counts()
# Out:
# education
# Bachelor's          36669
# Master's & above    14925
# Below Secondary       805
# Name: count, dtype: int64

# %%
hr_df.columns
# Out:
# Index(['department', 'region', 'education', 'gender', 'recruitment_channel',
#        'no_of_trainings', 'age', 'previous_year_rating', 'length_of_service',
#        'awards_won?', 'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
sns.barplot(x='previous_year_rating', y='is_promoted', data=hr_df)
plt.show();

# %%
sns.barplot(x='previous_year_rating', y='is_promoted', data=hr_df, palette='Set2')
plt.show();

# %%
sns.lineplot(x=hr_df['avg_training_score'], y=hr_df['is_promoted'])
plt.show()

# %%
sns.barplot(x='recruitment_channel', y='is_promoted', data=hr_df, palette='Set2')
plt.show();

# %%
hr_df['recruitment_channel'].value_counts()
# Out:
# recruitment_channel
# other       30446
# sourcing    23220
# referred     1142
# Name: count, dtype: int64

# %%
sns.barplot(x='gender', y='is_promoted', data=hr_df)
plt.show()

# %%
sns.barplot(x='department', y='is_promoted', data=hr_df)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.barplot(x='region', y='is_promoted', data=hr_df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.heatmap(hr_df[hr_df.select_dtypes(include=['int','float']).columns].corr(), cmap='coolwarm', annot=True)
plt.show()

# %% [markdown]
# ## 결측치 처리

# %%
hr_df.isna().mean()
# Out:
# department              0.000000
# region                  0.000000
# education               0.043953
# gender                  0.000000
# recruitment_channel     0.000000
# no_of_trainings         0.000000
# age                     0.000000
# previous_year_rating    0.075244
# length_of_service       0.000000
# awards_won?             0.000000
# avg_training_score      0.000000
# is_promoted             0.000000
# dtype: float64

# %%
hr_df['education'].value_counts()
# Out:
# education
# Bachelor's          36669
# Master's & above    14925
# Below Secondary       805
# Name: count, dtype: int64

# %%
hr_df['education'].fillna('unknown', inplace=True)

# %%
hr_df['previous_year_rating'].value_counts()
# Out:
# previous_year_rating
# 3.0    18618
# 5.0    11741
# 4.0     9877
# 1.0     6223
# 2.0     4225
# Name: count, dtype: int64

# %%
len(hr_df)
# Out:
# 54808

# %%
hr_df.dropna(inplace=True)

# %% [markdown]
# ## 더미 변수 변환

# %%
hr_df.head(3)
# Out:
#           department     region         education gender recruitment_channel  \
# 0  Sales & Marketing   region_7  Master's & above      f            sourcing
# 1         Operations  region_22        Bachelor's      m               other
# 2  Sales & Marketing  region_19        Bachelor's      m            sourcing
#
#    no_of_trainings  age  previous_year_rating  length_of_service  awards_won?  \
# 0                1   35                   5.0                  8            0
# 1                1   30                   5.0                  4            0
# 2                1   34                   3.0                  7            0
#
#    avg_training_score  is_promoted
# 0                  49            0
# 1                  60            0
# 2                  50            0

# %%
hr_df.select_dtypes('object').columns
# Out:
# Index(['department', 'region', 'education', 'gender', 'recruitment_channel'], dtype='object')

# %%
for col in hr_df.select_dtypes('object').columns:
  print(col, hr_df[col].nunique())
# Out:
# department 9
# region 34
# education 4
# gender 2
# recruitment_channel 3

# %%
hr_df = pd.get_dummies(hr_df, columns=['department', 'region', 'education', 'gender', 'recruitment_channel'])
hr_df.head()
# Out:
#    no_of_trainings  age  previous_year_rating  length_of_service  awards_won?  \
# 0                1   35                   5.0                  8            0
# 1                1   30                   5.0                  4            0
# 2                1   34                   3.0                  7            0
# 3                2   39                   1.0                 10            0
# 4                1   45                   3.0                  2            0
#
#    avg_training_score  is_promoted  department_Analytics  department_Finance  \
# 0                  49            0                 False               False
# 1                  60            0                 False               False
# 2                  50            0                 False               False
# 3                  50            0                 False               False
# 4                  73            0                 False               False
#
# ...

# %% [markdown]
# ## 모델링

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(hr_df.drop('is_promoted', axis=1), hr_df['is_promoted'], test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9238458503222412

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[13854,    31],
#        [ 1127,   194]])

# %%
class_report = classification_report(y_test, y_pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     13885
#            1       0.86      0.15      0.25      1321
#
#     accuracy                           0.92     15206
#    macro avg       0.89      0.57      0.61     15206
# weighted avg       0.92      0.92      0.90     15206

# %% [markdown]
# ## 해석 : 임의 데이터와 함께

# %%
X_train.head()
# Out:
#        no_of_trainings  age  previous_year_rating  length_of_service  \
# 9927                 1   33                   3.0                  8
# 50175                1   29                   4.0                  3
# 43058                2   30                   3.0                  4
# 34543                1   37                   3.0                  4
# 12495                1   36                   5.0                  8
#
#        awards_won?  avg_training_score  department_Analytics  \
# 9927             0                  50                 False
# 50175            0                  78                 False
# 43058            0                  87                  True
# 34543            0                  58                 False
# 12495            0                  59                 False
#
#        department_Finance  department_HR  department_Legal  ...  \
# 9927                False          False             False  ...
# ...

# %%
lr.coef_
# Out:
# array([[-2.63937664e-01, -4.43074136e-02,  3.62222257e-01,
#         -2.73182071e-02,  2.17304182e+00,  1.04015599e-01,
#         -1.87679309e+00, -1.21004664e-02, -5.30081886e-02,
#         -3.00648139e-01,  3.87413715e-01, -4.89073662e-01,
#         -1.63296123e+00,  1.15427825e+00, -1.29471525e+00,
#         -2.44016440e-02, -1.57179646e-01, -4.67376374e-01,
#         -1.93626599e-01, -1.98015706e-02, -5.52186916e-02,
#         -1.34998567e-01, -3.74117789e-01,  4.83105974e-01,
#         -9.93007798e-04, -1.51212482e-01,  1.48642693e-01,
#         -3.53926481e-01, -1.40157715e-01,  1.82470776e-01,
#          2.85053911e-01, -3.42397388e-01,  2.39191698e-01,
#         -3.55739153e-01, -7.14990769e-02,  3.20562658e-01,
#         -6.63477162e-01,  7.73559830e-02, -2.00932500e-02,
#         -5.68772952e-01, -5.49088723e-01, -1.53220316e-01,
#         -2.70656455e-01,  5.75259201e-01, -4.64713767e-01,
#         -4.23925999e-01,  2.65367517e-01, -3.13354555e-01,
# ...

# %%
temp_X = hr_df[['age', 'length_of_service']]
temy_y = hr_df['is_promoted']

# %%
temp_lr = LogisticRegression()
temp_lr.fit(temp_X, temy_y)
# Out:
# LogisticRegression()

# %%
df = pd.DataFrame({
    'age': [20, 21, 22],
    'length_of_service': [10, 15, 20]
})

# %%
pred = temp_lr.predict(df)
pred
# Out:
# array([0, 0, 0])

# %%
# 0일 확률, 1일 확률
proba = temp_lr.predict_proba(df)
proba
# Out:
# array([[0.90188998, 0.09811002],
#        [0.90276342, 0.09723658],
#        [0.90362992, 0.09637008]])

# %%
# age가 1 오를 때 -0.010023 만큼 기여
# length_of_service가 1 오를 때 0.0000225 만큼 기여
temp_lr.coef_
# Out:
# array([[-1.00231529e-02,  2.25233041e-05]])

# %%
# 절편
temp_lr.intercept_
# Out:
# array([-2.01816523])

# %%
coef_1 = -1.00231529e-02
coef_2 = 2.25233041e-05
inter = -2.01816523

# %%
1 / (1 + np.exp(-(coef_1* 20 + coef_2* 10 + inter)))
# Out:
# 0.0981100184288442

# %%
1 / (1 + np.exp(-(coef_1* 21 + coef_2* 15 + inter)))
# Out:
# 0.09723657616209705

# %%
1 / (1 + np.exp(-(coef_1* 22 + coef_2* 20 + inter)))
# Out:
# 0.09637007898351682

# %%
np.exp(coef_1)
# Out:
# 0.9900269114897317

# %%
np.exp(coef_2)
# Out:
# 1.0000225235577516

# %%
np.log(5)
# Out:
# 1.6094379124341003

# %%
np.exp(1.6094379124341003)
# Out:
# 4.999999999999999

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits = 10, random_state=42, shuffle=True)

# %%
for train_index, test_index in kf.split(range(len(hr_df))):
  X_train = hr_df.drop('is_promoted', axis=1).iloc[train_index]
  y_train = hr_df['is_promoted'].iloc[train_index]

  X_test = hr_df.drop('is_promoted', axis=1).iloc[test_index]
  y_test = hr_df['is_promoted'].iloc[test_index]

  lr = LogisticRegression()
  lr.fit(X_train, y_train)
  y_pred = lr.predict(X_test)
  pred_list = []
  print(accuracy_score(y_test, y_pred))
  pred_list.append(accuracy_score(y_test, y_pred))
# Out:
# 0.9208916946143223
# 0.927007299270073
# 0.9220753600315644
# 0.9283882422568553
# 0.9238358326756116
# 0.9210734017363852
# 0.9301499605367008
# 0.9236385161799526
# 0.9283741120757696
# 0.9208760852407262

# %%
print(np.mean(pred_list))
# Out:
# 0.9208760852407262
