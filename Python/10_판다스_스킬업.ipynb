# %% [markdown]
# # Ch10. 판다스 스킬업

# %% [markdown]
# ## 1. groupby 스킬업

# %% [markdown]
# `groupby`로 집계함수를 적용하면 다음과 같은 결과를 얻는다
#
# <img src=https://i.ibb.co/hRFtSTb/groupby.jpg, width=600>
#
#
# 그런데 왜 `pivot_table`을 두고 `groupby`로 집계함수를 적용하는 것일까?
# - 실제로는 `groupby`로 집계를 하는 경우가 더 많다
# - `groupby`는 `agg`와 `transfrom` 등과 결합해 보다 유용한 집계를 할 수 있다

# %%
# 실습 준비 코드
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format # 소수점 출력옵션
data = [['김판다', 'A', '남', 95, 77], ['송중기', 'B', '남', 93, 92],
        ['김나현', 'B', '여', 88, 60], ['박효신', 'A', '남', 85, 83],
        ['강승주', 'B', '여', 78, 92], ['권보아', 'A', '여', 72, 75]]
df = pd.DataFrame(data, columns=['이름', '반', '성별', '국어', '수학'])
df
# Out:
#     이름  반 성별  국어  수학
# 0  김판다  A  남  95  77
# 1  송중기  B  남  93  92
# 2  김나현  B  여  88  60
# 3  박효신  A  남  85  83
# 4  강승주  B  여  78  92
# 5  권보아  A  여  72  75

# %%
# groupby로 집계함수 적용하기 복습
df.groupby(['반', '성별'])['국어'].mean()
# Out:
# 반  성별
# A  남    90.00
#    여    72.00
# B  남    93.00
#    여    83.00
# Name: 국어, dtype: float64

# %% [markdown]
# **groupby 스킬업1**
#
# 복수의 열에 `groupby`를 적용하자

# %%
# data도 복수로 지정이 가능하다 (사실 data는 대괄호 인덱싱)
df.groupby(['반', '성별'])[['국어', '수학']].mean()
# Out:
#         국어    수학
# 반 성별
# A 남  90.00 80.00
#   여  72.00 75.00
# B 남  93.00 92.00
#   여  83.00 76.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      6 non-null      object
#  1   반       6 non-null      object
#  2   성별      6 non-null      object
#  3   국어      6 non-null      int64
#  4   수학      6 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 368.0+ bytes

# %%
# 인덱싱을 하지 않으면 전체에 적용한다 (단 by에 지정된 열은 제외)
df.groupby(['반', '성별']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    2453                 "mean",
# -> 2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455                 numeric_only=numeric_only,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6456                 )
# -> 6457             return op(delegate, skipna=skipna, **kwds)
#    6458
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     403
# --> 404         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     405
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     719     the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720     the_sum = _ensure_numeric(the_sum)
#     721
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1700             # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701             raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702         try:
#
# TypeError: Could not convert string '김판다박효신' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-309ca9edf931> in <cell line: 2>()
#       1 # 인덱싱을 하지 않으면 전체에 적용한다 (단 by에 지정된 열은 제외)
# ----> 2 df.groupby(['반', '성별']).mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only, engine, engine_kwargs)
#    2450             )
#    2451         else:
# -> 2452             result = self._cython_agg_general(
#    2453                 "mean",
#    2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1996             return result
#    1997
# -> 1998         new_mgr = data.grouped_reduce(array_func)
#    1999         res = self._wrap_agged_manager(new_mgr)
#    2000         if how in ["idxmin", "idxmax"]:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in grouped_reduce(self, func)
#    1467                 #  while others do not.
#    1468                 for sb in blk._split():
# -> 1469                     applied = sb.apply(func)
#    1470                     result_blocks = extend_blocks(applied, result_blocks)
#    1471             else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     391         one
#     392         """
# --> 393         result = func(self.values, **kwargs)
#     394
#     395         result = maybe_coerce_values(result)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1993
#    1994             assert alt is not None
# -> 1995             result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996             return result
#    1997
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1944             msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945             # preserve the kind of exception that raised
# -> 1946             raise type(err)(msg) from err
#    1947
#    1948         if ser.dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %% [markdown]
# **groupby 스킬업2**
#
# `groupby`로 집계함수를 사용하면 `agg`와 함께 집계함수를 사용가능하다
#
# **agg의 장점**
#
# 1. `agg` 와 리스트를 이용하면 튜플로 집계결과의 열이름을 바꿀 수 있다
#
# 2. 복수의 집계함수 사용가능
#
# 3. 열마다 다른 집계함수 사용가능
#
# 4. lambda 함수 사용가능
#
# 1은 `set_axis`등으로 손쉽게 가능하고 2, 4는 `pivot_table`로도 가능하므로 실질적 장점은 3이다

# %%
# 함수를 튜플로 입력해 열 이름을 바꿀 수 있다
df.groupby(['반'])['국어'].agg([('국어평균', 'mean')])
# Out:
#    국어평균
# 반
# A 84.00
# B 86.33

# %%
# 복수의 집계함수 적용
df.groupby(['반'])['국어'].agg(['mean', 'std'])
# Out:
#    mean   std
# 반
# A 84.00 11.53
# B 86.33  7.64

# %%
# 위 결과는 피벗 테이블로도 가능하다
df.pivot_table('국어', index='반', aggfunc=['mean', 'max']).droplevel(1, axis=1)
# Out:
#    mean  max
# 반
# A 84.00   95
# B 86.33   93

# %%
# 복수의 집계함수 일 때도 열 이름을 바꿀 수 있다
df.groupby(['반'])['국어'].agg([('국어평균', 'mean'), ('표준편차','max')])
# Out:
#    국어평균  표준편차
# 반
# A 84.00    95
# B 86.33    93

# %%
# 열마다 다른 집계함수 적용
df.groupby(['반']).agg({'국어': 'mean', '수학': 'count'})
# Out:
#      국어  수학
# 반
# A 84.00   3
# B 86.33   3

# %%
# lambda 함수도 사용 가능하다. 반별 수학 점수가 90 이상인 인원수
df.groupby(['반'])['수학'].agg(lambda x: (x > 80).sum())
# Out:
# 반
# A    1
# B    2
# Name: 수학, dtype: int64

# %% [markdown]
# **groupby 스킬업3**
#
# - `transform`과 집계함수를 이용해 집계 결과를 열로 만들수 있다
#
# -  열로 만들수 있으므로 집계 결과로 불리언 인덱싱도 할 수 있다

# %%
# transform은 집계함수의 적용 결과를 원본 df와 같은 길이의 시리즈로 반환한다
df.groupby('반')['수학'].transform('mean')
# Out:
# 0   78.33
# 1   81.33
# 2   81.33
# 3   78.33
# 4   81.33
# 5   78.33
# Name: 수학, dtype: float64

# %%
# 반평균보다 점수가 높은 학생들의 데이터만 필터링
cond1 = df['수학'] > df.groupby('반')['수학'].transform('mean')
df[cond1]
# Out:
#     이름  반 성별  국어  수학
# 1  송중기  B  남  93  92
# 3  박효신  A  남  85  83
# 4  강승주  B  여  78  92

# %% [markdown]
# ## 2. apply 스킬업

# %% [markdown]
# 시리즈에 적용할 때와 데이터프레임에 적용할 때의 apply의 차이
#
# <img src=https://i.ibb.co/XsLBD3W/apply.jpg, width=600>
#
#
# apply가 잘 기억 안나는 분들은 링크 참조 :
# https://kimpanda.tistory.com/86

# %%
# 실습 준비 코드
import pandas as pd
data = [['82점', '81점', '77점'], ['91점', '95점', '83점'],
         ['78점', '72점', '88점'], ['82점', '87점', '72점']]
s1 = pd.Series(['80점', '75점', '77점', '60점'])
s2 = pd.Series(['4등', '3등', '1등', '2등'], index=list('ABCD'))
s3 = pd.Series(['없음', '사오기', '만원', '2만원'],
               index=['1등', '2등', '3등', '4등'])
df = pd.DataFrame(data, index=list('ABCD'), columns=['국어', '영어', '수학'])
df
# Out:
#     국어   영어   수학
# A  82점  81점  77점
# B  91점  95점  83점
# C  78점  72점  88점
# D  82점  87점  72점

# %% [markdown]
# apply와 map의 차이

# %%
# 시리즈에 apply 적용하기
s1.apply(lambda x: int(x[:-1]))
# Out:
# 0    80
# 1    75
# 2    77
# 3    60
# dtype: int64

# %%
# map 함수는 시리즈에 적용할 때 apply와 유사하다
s1.map(lambda x: int(x[:-1]))
# Out:
# 0    80
# 1    75
# 2    77
# 3    60
# dtype: int64

# %%
# apply와 map의 차이점을 알기 위해 s2와 s3를 이용하자
print(s2)
print(s3)
# Out:
# A    4등
# B    3등
# C    1등
# D    2등
# dtype: object
# 1등     없음
# 2등    사오기
# 3등     만원
# 4등    2만원
# dtype: object

# %%
# map 함수는 함수대신 맵퍼를 입력받을 수 있다
s2.map(s3)
# Out:
# A    2만원
# B     만원
# C     없음
# D    사오기
# dtype: object

# %%
# apply는 맵퍼를 입력받지 못하지만 lambda 함수로 유사한 기능 가능
s2.apply(lambda x: s3[x])
# Out:
# A    2만원
# B     만원
# C     없음
# D    사오기
# dtype: object

# %% [markdown]
# apply와 applymap의 차이

# %%
# 실습에 쓰일 df 출력
df
# Out:
#     국어   영어   수학
# A  82점  81점  77점
# B  91점  95점  83점
# C  78점  72점  88점
# D  82점  87점  72점

# %%
# applymap은 apply와 달리 데이터 프레임도 셀마다 함수를 적용한다
df.applymap(lambda x: int(x[:-1]))
# Out:
# <ipython-input-26-f635adca1c6d>:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: int(x[:-1]))
#    국어  영어  수학
# A  82  81  77
# B  91  95  83
# C  78  72  88
# D  82  87  72

# %%
# 위 결과를 apply로 얻으려면 map 함수를 한번 더 사용해야 한다
df.apply(lambda x: x.map(lambda y: int(y[:-1])))
# Out:
#    국어  영어  수학
# A  82  81  77
# B  91  95  83
# C  78  72  88
# D  82  87  72

# %% [markdown]
# <img src=https://i.ibb.co/2sMGLVz/10-02.png, width=600>

# %% [markdown]
# apply, map, applymap의 차이 참고 강의 링크 : https://youtu.be/upY7WRenFjo

# %% [markdown]
# ## 3. 데이터 구조 바꾸기 스킬업

# %% [markdown]
# > pandas explode
#
# <img src=https://i.ibb.co/XV1n3kJ/10-03.png, width=600>
#
# 데이터프레임이나 시리즈의 셀안에 있는 리스트의 데이터를 확장하는 함수

# %%
# 실습 준비 코드
import pandas as pd
pd.options.display.max_rows = 6 # 판다스 버전업에 따라 6행만 출력의 바뀐 코드
df1 = pd.DataFrame([[95, ['김판다', '강승주']], [92, '송중기']],
                   columns=['점수', '이름'])
df2 = pd.DataFrame([[95, '김판다/강승주'], [92, '송중기']],
                   columns=['점수', '이름'])

# %%
# 실습에 쓰일 df1. df1은 셀에 리스트를 갖고 있다
df1
# Out:
#    점수          이름
# 0  95  [김판다, 강승주]
# 1  92         송중기

# %%
# explode 함수로 리스트의 데이터를 분리할 수 있다
df1.explode('이름')
# Out:
#    점수   이름
# 0  95  김판다
# 0  95  강승주
# 1  92  송중기

# %%
# 왜 데이터에 리스트가 있는걸까? 보통의 경우 우리가 만드는 것이다
df2
# Out:
#    점수       이름
# 0  95  김판다/강승주
# 1  92      송중기

# %%
# 이름열의 /를 분리해서 리스트로 만들고 explode를 사용하면 전처리된다
df2['이름'] = df2['이름'].str.split('/')
df2.explode('이름')
# Out:
#    점수   이름
# 0  95  김판다
# 0  95  강승주
# 1  92  송중기

# %% [markdown]
# **explode 함수 실습하기**
#
# 작품으로 나열된 네이버 웹툰의 데이터를 이용해 작가 중심으로 해당 작가의 작품을 묶어보자
#
# 네이버 웹툰 데이터 : https://raw.githubusercontent.com/panda-kim/csv_files/main/naver.csv

# %%
url = 'https://raw.githubusercontent.com/panda-kim/csv_files/main/naver.csv'
df_ex1 = pd.read_csv(url, usecols=['title', 'author'])
df_ex1
# Out:
#                   title      author
# 0          가난을 등에 업은 소녀  B급달궁 / 오은지
# 1                  가담항설          랑또
# 2          가령의 정체불명 이야기          가령
# ...                 ...         ...
# 1853    [드라마원작] 한번 더 해요     미티 / 구구
# 1854  [드라마원작] 내 ID는 ...         기맹기
# 1855  [드라마원작] 지금 우리 ...         주동근
#
# [1856 rows x 2 columns]

# %%
df_ex2 = df_ex1.copy()
df_ex2['author'] = df_ex2['author'].str.split(' / ')
df_ex2.explode('author').groupby('author', as_index=False)['title'].agg(' / '.join)
# Out:
#      author                       title
# 0       -2℃                   헬 인 파라다이스
# 1       0환이                        가짜인간
# 2       12B                         뱀피르
# ...     ...                         ...
# 1737     히디                     시월드 판타지
# 1738    히어리  꽃미남 저승사자 / 재혼 황후 / 하렘의 남자들
# 1739    힐링달                       인싸라이프
#
# [1740 rows x 2 columns]

# %%
# join 함수는 시리즈의 문자열을 합치는 함수이다
s = pd.Series(['a', 'bc'])
'/'.join(s)
# Out:
# 'a/bc'

# %% [markdown]
# ## 4. 시각화 스킬업

# %% [markdown]
# **파이썬 시각화를 학습할 때의 문제점**
# - 대부분 시각화 라이브러리를 제대로 쓰려면 matplotlib부터 배워야 한다
# - 그래서 정작 그래프는 그리지 않는 matplotlib만 배우고 끝나는 경우가 많다

# %% [markdown]
# **판다스의 시각화**
# - 데이터 프레임에 바로 함수를 적용해 간단한 코드로 시각화가 가능한 라이브러리들이 많다
#
#   ex) seaborn, pandas-bokeh
# - 다만 꼭 matplotlib가 아니더라도 제대로 쓰려면 여전히 기반 라이브러리를  배워야 한다
#
#   ex) seaborn은 matplotlib 기반, pandas-bokeh는 bokeh 기반
#
# → 기반 라이브러리를 많이 써야 할 수록 판다스 시각화의 간결함의 장점이 사라진다

# %% [markdown]
# **해결책**
# - 데이터 프레임에 바로 함수를 적용해 간결한 코드로 판다스의 시각화가 가능하며
# - 가급적 기반 라이브러리를 사용하고 않고 해당 판다스 시각화 라이브러리 자체로 해결이 가능
# - 반응형 그래프를 그릴 수 있는 라이브러리
#
# 위와 같은 라이브러리라면 간결하고 예쁜 시각화가 손쉽게 가능하다
#
# -> pyechart 기반의 pandasecharts를 배워보자

# %% [markdown]
# **pyecharts**
#
# echarts를 python에서 사용할 수 있게 해주는 라이브러리
#
# - 기본값이 예쁘다
# - 반응형이다
#
# pyecharts 사이트 링크 : https://pyecharts.org/#/en-us/
#
# 갤러리 링크 : https://gallery.pyecharts.org/#/README_EN
#
# pyecharts 설치 (1.9.1버전 설치)
#
# ```python
# !pip install --upgrade pyecharts==1.9.1
# ```
#
# **pandasecharts**
#
# 데이터 프레임에 pyecharts를 쉽게 사용하게 해주는 라이브러리
#
#
#
#
# pandasecharts 설치
#
# ```python
# !pip install pandasecharts
# ```

# %%
# pyecharts 1.9.1 설치
# !pip install --upgrade pyecharts==1.9.1
# Out:
# Collecting pyecharts==1.9.1
#   Downloading pyecharts-1.9.1-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from pyecharts==1.9.1) (3.1.4)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from pyecharts==1.9.1) (3.11.0)
# Collecting simplejson (from pyecharts==1.9.1)
#   Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->pyecharts==1.9.1) (3.0.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->pyecharts==1.9.1) (0.2.13)
# Downloading pyecharts-1.9.1-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 4.5 MB/s eta 0:00:00
# Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 10.0 MB/s eta 0:00:00
# Installing collected packages: simplejson, pyecharts
# Successfully installed pyecharts-1.9.1 simplejson-3.19.3

# %%
# pandasecharts 설치
# !pip install pandasecharts
# Out:
# Collecting pandasecharts
#   Downloading pandasecharts-0.5-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandasecharts) (2.2.2)
# Requirement already satisfied: pyecharts>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pandasecharts) (1.9.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from pyecharts>=1.0.0->pandasecharts) (3.1.4)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from pyecharts>=1.0.0->pandasecharts) (3.11.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.10/dist-packages (from pyecharts>=1.0.0->pandasecharts) (3.19.3)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->pandasecharts) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pandasecharts) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandasecharts) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->pandasecharts) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->pandasecharts) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->pyecharts>=1.0.0->pandasecharts) (3.0.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->pyecharts>=1.0.0->pandasecharts) (0.2.13)
# Downloading pandasecharts-0.5-py3-none-any.whl (15 kB)
# Installing collected packages: pandasecharts
# Successfully installed pandasecharts-0.5

# %%
# 실습 준비코드
import pandas as pd
from pyecharts.globals import ThemeType
from pyecharts.charts import Timeline
from pandasecharts import echart
import IPython
data1 = [['강승주', 98, 72], ['김판다', 89, 91],
         ['박효신', 77, 78], ['손승연', 62, 93]]
data2 = [['강승주', 72, 79], ['김판다', 83, 81],
         ['박효신', 74, 87], ['손승연', 92, 89]]
df1 = pd.DataFrame(data1, columns=['이름', '국어', '영어'])
df2 = pd.DataFrame(data2, columns=['이름', '국어', '영어'])

# %%
# bar 그래프 그리기(render.html 파일로 저장)
df1.echart.bar(x='이름', ys=['국어', '영어'], figsize=(600,400)).render()
IPython.display.HTML(filename='/content/render.html') # 코랩에서 출력
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#
# </head>
# <body>
#     <div id="6f07911508d84a3cb488c66c598e9bb2" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_6f07911508d84a3cb488c66c598e9bb2 = echarts.init(
#             document.getElementById('6f07911508d84a3cb488c66c598e9bb2'), 'white', {renderer: 'canvas'});
#         var option_6f07911508d84a3cb488c66c598e9bb2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\uad6d\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 98,
#                 89,
#                 77,
#                 62
#             ],
#             "showBackground": false,
#             "stack": "1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\uc601\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 72,
#                 91,
#                 78,
#                 93
#             ],
#             "showBackground": false,
#             "stack": "2",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uad6d\uc5b4",
#                 "\uc601\uc5b4"
#             ],
#             "selected": {
#                 "\uad6d\uc5b4": true,
#                 "\uc601\uc5b4": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "name": "\uc774\ub984",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\uac15\uc2b9\uc8fc",
#                 "\uae40\ud310\ub2e4",
#                 "\ubc15\ud6a8\uc2e0",
#                 "\uc190\uc2b9\uc5f0"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_6f07911508d84a3cb488c66c598e9bb2.setOption(option_6f07911508d84a3cb488c66c598e9bb2);
#     </script>
# </body>
# </html>

# %%
# 저장 파일명 바꾸기
df1.echart.bar(x='이름', ys=['국어', '영어']).render('파일명.html')
IPython.display.HTML(filename='/content/파일명.html') # 코랩에서 출력
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#
# </head>
# <body>
#     <div id="2b82732d8e8047029e5886a52a3dea13" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_2b82732d8e8047029e5886a52a3dea13 = echarts.init(
#             document.getElementById('2b82732d8e8047029e5886a52a3dea13'), 'white', {renderer: 'canvas'});
#         var option_2b82732d8e8047029e5886a52a3dea13 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\uad6d\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 98,
#                 89,
#                 77,
#                 62
#             ],
#             "showBackground": false,
#             "stack": "1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\uc601\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 72,
#                 91,
#                 78,
#                 93
#             ],
#             "showBackground": false,
#             "stack": "2",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uad6d\uc5b4",
#                 "\uc601\uc5b4"
#             ],
#             "selected": {
#                 "\uad6d\uc5b4": true,
#                 "\uc601\uc5b4": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "name": "\uc774\ub984",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\uac15\uc2b9\uc8fc",
#                 "\uae40\ud310\ub2e4",
#                 "\ubc15\ud6a8\uc2e0",
#                 "\uc190\uc2b9\uc5f0"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_2b82732d8e8047029e5886a52a3dea13.setOption(option_2b82732d8e8047029e5886a52a3dea13);
#     </script>
# </body>
# </html>

# %%
# 저장 않고 노트북으로 출력(코랩에서는 되지 않는다)
df1.echart.bar(x='이름', ys=['국어', '영어']).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5595e9177c764e0ca1c64dc8863b88af" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5595e9177c764e0ca1c64dc8863b88af = echarts.init(
#                     document.getElementById('5595e9177c764e0ca1c64dc8863b88af'), 'white', {renderer: 'canvas'});
#                 var option_5595e9177c764e0ca1c64dc8863b88af = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\uad6d\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 98,
#                 89,
#                 77,
#                 62
#             ],
#             "showBackground": false,
#             "stack": "1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\uc601\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 72,
#                 91,
#                 78,
#                 93
#             ],
#             "showBackground": false,
#             "stack": "2",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uad6d\uc5b4",
#                 "\uc601\uc5b4"
#             ],
#             "selected": {
#                 "\uad6d\uc5b4": true,
#                 "\uc601\uc5b4": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "name": "\uc774\ub984",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\uac15\uc2b9\uc8fc",
#                 "\uae40\ud310\ub2e4",
#                 "\ubc15\ud6a8\uc2e0",
#                 "\uc190\uc2b9\uc5f0"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_5595e9177c764e0ca1c64dc8863b88af.setOption(option_5595e9177c764e0ca1c64dc8863b88af);
#         });
#     </script>

# %%
# 크기 변경
df1.echart.bar(x='이름', ys=['국어', '영어'], figsize=(600,400)).render()
IPython.display.HTML(filename='/content/render.html') # 코랩에서 출력
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#
# </head>
# <body>
#     <div id="769eba147c554a428e5d0d645fa09c72" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_769eba147c554a428e5d0d645fa09c72 = echarts.init(
#             document.getElementById('769eba147c554a428e5d0d645fa09c72'), 'white', {renderer: 'canvas'});
#         var option_769eba147c554a428e5d0d645fa09c72 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\uad6d\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 98,
#                 89,
#                 77,
#                 62
#             ],
#             "showBackground": false,
#             "stack": "1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\uc601\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 72,
#                 91,
#                 78,
#                 93
#             ],
#             "showBackground": false,
#             "stack": "2",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uad6d\uc5b4",
#                 "\uc601\uc5b4"
#             ],
#             "selected": {
#                 "\uad6d\uc5b4": true,
#                 "\uc601\uc5b4": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "name": "\uc774\ub984",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\uac15\uc2b9\uc8fc",
#                 "\uae40\ud310\ub2e4",
#                 "\ubc15\ud6a8\uc2e0",
#                 "\uc190\uc2b9\uc5f0"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_769eba147c554a428e5d0d645fa09c72.setOption(option_769eba147c554a428e5d0d645fa09c72);
#     </script>
# </body>
# </html>

# %%
# 국어열의 값에 따라 정렬
df1.echart.bar(x='이름', ys=['국어', '영어'], sort='국어', figsize=(600,400)).render()
IPython.display.HTML(filename='/content/render.html') # 코랩에서 출력
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#
# </head>
# <body>
#     <div id="467c64db8e014c53aa5380ecf2c66e69" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_467c64db8e014c53aa5380ecf2c66e69 = echarts.init(
#             document.getElementById('467c64db8e014c53aa5380ecf2c66e69'), 'white', {renderer: 'canvas'});
#         var option_467c64db8e014c53aa5380ecf2c66e69 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\uad6d\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 98,
#                 89,
#                 77,
#                 62
#             ],
#             "showBackground": false,
#             "stack": "1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\uc601\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 72,
#                 91,
#                 78,
#                 93
#             ],
#             "showBackground": false,
#             "stack": "2",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uad6d\uc5b4",
#                 "\uc601\uc5b4"
#             ],
#             "selected": {
#                 "\uad6d\uc5b4": true,
#                 "\uc601\uc5b4": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "name": "\uc774\ub984",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\uac15\uc2b9\uc8fc",
#                 "\uae40\ud310\ub2e4",
#                 "\ubc15\ud6a8\uc2e0",
#                 "\uc190\uc2b9\uc5f0"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_467c64db8e014c53aa5380ecf2c66e69.setOption(option_467c64db8e014c53aa5380ecf2c66e69);
#     </script>
# </body>
# </html>

# %%
# 제목 생성
df1.echart.bar(x='이름', ys=['국어', '영어'], title='중간고사',
               figsize=(600,400)).render()
IPython.display.HTML(filename='/content/render.html') # 코랩에서 출력
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#
# </head>
# <body>
#     <div id="7cab2ddf7abc49a5a20d19ebca6b2f0b" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_7cab2ddf7abc49a5a20d19ebca6b2f0b = echarts.init(
#             document.getElementById('7cab2ddf7abc49a5a20d19ebca6b2f0b'), 'white', {renderer: 'canvas'});
#         var option_7cab2ddf7abc49a5a20d19ebca6b2f0b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\uad6d\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 98,
#                 89,
#                 77,
#                 62
#             ],
#             "showBackground": false,
#             "stack": "1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\uc601\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 72,
#                 91,
#                 78,
#                 93
#             ],
#             "showBackground": false,
#             "stack": "2",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uad6d\uc5b4",
#                 "\uc601\uc5b4"
#             ],
#             "selected": {
#                 "\uad6d\uc5b4": true,
#                 "\uc601\uc5b4": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "name": "\uc774\ub984",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\uac15\uc2b9\uc8fc",
#                 "\uae40\ud310\ub2e4",
#                 "\ubc15\ud6a8\uc2e0",
#                 "\uc190\uc2b9\uc5f0"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\uc911\uac04\uace0\uc0ac",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_7cab2ddf7abc49a5a20d19ebca6b2f0b.setOption(option_7cab2ddf7abc49a5a20d19ebca6b2f0b);
#     </script>
# </body>
# </html>

# %%
# 소제목(subtitle) 생성
df1.echart.bar(x='이름', ys=['국어', '영어'], title='중간고사',
               subtitle='누가누가잘했나', figsize=(600,400)).render()
IPython.display.HTML(filename='/content/render.html') # 코랩에서 출력
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#
# </head>
# <body>
#     <div id="7d7c6d7a806048a2845d11465a01111b" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_7d7c6d7a806048a2845d11465a01111b = echarts.init(
#             document.getElementById('7d7c6d7a806048a2845d11465a01111b'), 'white', {renderer: 'canvas'});
#         var option_7d7c6d7a806048a2845d11465a01111b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\uad6d\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 98,
#                 89,
#                 77,
#                 62
#             ],
#             "showBackground": false,
#             "stack": "1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\uc601\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 72,
#                 91,
#                 78,
#                 93
#             ],
#             "showBackground": false,
#             "stack": "2",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uad6d\uc5b4",
#                 "\uc601\uc5b4"
#             ],
#             "selected": {
#                 "\uad6d\uc5b4": true,
#                 "\uc601\uc5b4": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "name": "\uc774\ub984",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\uac15\uc2b9\uc8fc",
#                 "\uae40\ud310\ub2e4",
#                 "\ubc15\ud6a8\uc2e0",
#                 "\uc190\uc2b9\uc5f0"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\uc911\uac04\uace0\uc0ac",
#             "subtext": "\ub204\uac00\ub204\uac00\uc798\ud588\ub098",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_7d7c6d7a806048a2845d11465a01111b.setOption(option_7d7c6d7a806048a2845d11465a01111b);
#     </script>
# </body>
# </html>

# %%
# 수치 표현하기
df1.echart.bar(x='이름', ys=['국어', '영어'], title='중간고사',
               subtitle='누가누가잘했나', label_show=True, figsize=(600,400)).render()
IPython.display.HTML(filename='/content/render.html') # 코랩에서 출력
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#
# </head>
# <body>
#     <div id="4ffd113151e24711bbea5e7cd7a6cf6b" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_4ffd113151e24711bbea5e7cd7a6cf6b = echarts.init(
#             document.getElementById('4ffd113151e24711bbea5e7cd7a6cf6b'), 'white', {renderer: 'canvas'});
#         var option_4ffd113151e24711bbea5e7cd7a6cf6b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\uad6d\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 98,
#                 89,
#                 77,
#                 62
#             ],
#             "showBackground": false,
#             "stack": "1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\uc601\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 72,
#                 91,
#                 78,
#                 93
#             ],
#             "showBackground": false,
#             "stack": "2",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uad6d\uc5b4",
#                 "\uc601\uc5b4"
#             ],
#             "selected": {
#                 "\uad6d\uc5b4": true,
#                 "\uc601\uc5b4": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "name": "\uc774\ub984",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\uac15\uc2b9\uc8fc",
#                 "\uae40\ud310\ub2e4",
#                 "\ubc15\ud6a8\uc2e0",
#                 "\uc190\uc2b9\uc5f0"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\uc911\uac04\uace0\uc0ac",
#             "subtext": "\ub204\uac00\ub204\uac00\uc798\ud588\ub098",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_4ffd113151e24711bbea5e7cd7a6cf6b.setOption(option_4ffd113151e24711bbea5e7cd7a6cf6b);
#     </script>
# </body>
# </html>

# %% [markdown]
# **pyecharts 테마**
# - LIGHT
# - DARK
# - CHALK
# - ESSOS
# - INFOGRAPHIC
# - MACARONS
# - PURPLE_PASSION
# - ROMA
# - ROMANTIC
# - SHINE
# - VINTAGE
#
# 다음 링크로 테마를 확인해볼 수 있다: https://pyecharts.org/#/en-us/themes?id=theme-style

# %%
# 테마 변경
df1.echart.bar(x='이름', ys=['국어', '영어'], title='중간고사', figsize=(600,400),
               subtitle='누가누가 잘했나', theme=ThemeType.DARK).render()
IPython.display.HTML(filename='/content/render.html')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#
# </head>
# <body>
#     <div id="0b91cb2a34de470ebead42faebe9bc4a" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_0b91cb2a34de470ebead42faebe9bc4a = echarts.init(
#             document.getElementById('0b91cb2a34de470ebead42faebe9bc4a'), 'dark', {renderer: 'canvas'});
#         var option_0b91cb2a34de470ebead42faebe9bc4a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\uad6d\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 98,
#                 89,
#                 77,
#                 62
#             ],
#             "showBackground": false,
#             "stack": "1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\uc601\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 72,
#                 91,
#                 78,
#                 93
#             ],
#             "showBackground": false,
#             "stack": "2",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uad6d\uc5b4",
#                 "\uc601\uc5b4"
#             ],
#             "selected": {
#                 "\uad6d\uc5b4": true,
#                 "\uc601\uc5b4": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "name": "\uc774\ub984",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\uac15\uc2b9\uc8fc",
#                 "\uae40\ud310\ub2e4",
#                 "\ubc15\ud6a8\uc2e0",
#                 "\uc190\uc2b9\uc5f0"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\uc911\uac04\uace0\uc0ac",
#             "subtext": "\ub204\uac00\ub204\uac00 \uc798\ud588\ub098",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_0b91cb2a34de470ebead42faebe9bc4a.setOption(option_0b91cb2a34de470ebead42faebe9bc4a);
#     </script>
# </body>
# </html>

# %%
# 함수 및 인자 정리
(df1
 .echart.bar(x='이름',
             ys=['국어', '영어'],
             sort='영어',
             title='중간고사',
             subtitle='결과',
             figsize=(600,400),
             theme=ThemeType.DARK
             )
 .render()
 )
IPython.display.HTML(filename='/content/render.html')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#
# </head>
# <body>
#     <div id="9dd50f6542cf482fb67b99fe04634f1d" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_9dd50f6542cf482fb67b99fe04634f1d = echarts.init(
#             document.getElementById('9dd50f6542cf482fb67b99fe04634f1d'), 'dark', {renderer: 'canvas'});
#         var option_9dd50f6542cf482fb67b99fe04634f1d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\uad6d\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 62,
#                 89,
#                 77,
#                 98
#             ],
#             "showBackground": false,
#             "stack": "1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\uc601\uc5b4",
#             "legendHoverLink": true,
#             "data": [
#                 93,
#                 91,
#                 78,
#                 72
#             ],
#             "showBackground": false,
#             "stack": "2",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\uad6d\uc5b4",
#                 "\uc601\uc5b4"
#             ],
#             "selected": {
#                 "\uad6d\uc5b4": true,
#                 "\uc601\uc5b4": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "name": "\uc774\ub984",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\uc190\uc2b9\uc5f0",
#                 "\uae40\ud310\ub2e4",
#                 "\ubc15\ud6a8\uc2e0",
#                 "\uac15\uc2b9\uc8fc"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\uc911\uac04\uace0\uc0ac",
#             "subtext": "\uacb0\uacfc",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_9dd50f6542cf482fb67b99fe04634f1d.setOption(option_9dd50f6542cf482fb67b99fe04634f1d);
#     </script>
# </body>
# </html>

# %%
# 타임라인
tl = Timeline({'width':'600px', 'height':'400px'})
bar1 = df1.echart.bar(x='이름', ys=['국어', '영어'], title='1학기', subtitle='중간고사',theme=ThemeType.DARK)
bar2 = df2.echart.bar(x='이름', ys=['국어', '영어'], title='1학기', subtitle='기말고사',theme=ThemeType.DARK)
tl.add(bar1, '중간고사').add(bar2, '기말고사').render()
IPython.display.HTML(filename='/content/render.html')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#
# </head>
# <body>
#     <div id="11c68e1ef571429690599b895392c6ac" class="chart-container" style="width:600px; height:400px;"></div>
#     <script>
#         var chart_11c68e1ef571429690599b895392c6ac = echarts.init(
#             document.getElementById('11c68e1ef571429690599b895392c6ac'), 'white', {renderer: 'canvas'});
#         var option_11c68e1ef571429690599b895392c6ac = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "\uad6d\uc5b4",
#                 "legendHoverLink": true,
#                 "data": [
#                     72,
#                     83,
#                     74,
#                     92
#                 ],
#                 "showBackground": false,
#                 "stack": "1",
#                 "barMinHeight": 0,
#                 "barCategoryGap": "20%",
#                 "barGap": "30%",
#                 "large": false,
#                 "largeThreshold": 400,
#                 "seriesLayoutBy": "column",
#                 "datasetIndex": 0,
#                 "clip": true,
#                 "zlevel": 0,
#                 "z": 2,
#                 "label": {
#                     "show": false,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "rippleEffect": {
#                     "show": true,
#                     "brushType": "stroke",
#                     "scale": 2.5,
#                     "period": 4
#                 }
#             },
#             {
#                 "type": "bar",
#                 "name": "\uc601\uc5b4",
#                 "legendHoverLink": true,
#                 "data": [
#                     79,
#                     81,
#                     87,
#                     89
#                 ],
#                 "showBackground": false,
#                 "stack": "2",
#                 "barMinHeight": 0,
#                 "barCategoryGap": "20%",
#                 "barGap": "30%",
#                 "large": false,
#                 "largeThreshold": 400,
#                 "seriesLayoutBy": "column",
#                 "datasetIndex": 0,
#                 "clip": true,
#                 "zlevel": 0,
#                 "z": 2,
#                 "label": {
#                     "show": false,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "rippleEffect": {
#                     "show": true,
#                     "brushType": "stroke",
#                     "scale": 2.5,
#                     "period": 4
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "\uc911\uac04\uace0\uc0ac",
#                 "\uae30\ub9d0\uace0\uc0ac"
#             ]
#         },
#         "xAxis": [
#             {
#                 "type": "category",
#                 "name": "\uc774\ub984",
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "\uac15\uc2b9\uc8fc",
#                     "\uae40\ud310\ub2e4",
#                     "\ubc15\ud6a8\uc2e0",
#                     "\uc190\uc2b9\uc5f0"
#                 ]
#             }
#         ],
#         "yAxis": [
#             {
#                 "type": "value",
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 }
#             }
#         ]
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "\uad6d\uc5b4",
#                         "\uc601\uc5b4"
#                     ],
#                     "selected": {
#                         "\uad6d\uc5b4": true,
#                         "\uc601\uc5b4": true
#                     },
#                     "show": true,
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "bar",
#                     "name": "\uad6d\uc5b4",
#                     "legendHoverLink": true,
#                     "data": [
#                         98,
#                         89,
#                         77,
#                         62
#                     ],
#                     "showBackground": false,
#                     "stack": "1",
#                     "barMinHeight": 0,
#                     "barCategoryGap": "20%",
#                     "barGap": "30%",
#                     "large": false,
#                     "largeThreshold": 400,
#                     "seriesLayoutBy": "column",
#                     "datasetIndex": 0,
#                     "clip": true,
#                     "zlevel": 0,
#                     "z": 2,
#                     "label": {
#                         "show": false,
#                         "position": "top",
#                         "margin": 8
#                     },
#                     "rippleEffect": {
#                         "show": true,
#                         "brushType": "stroke",
#                         "scale": 2.5,
#                         "period": 4
#                     }
#                 },
#                 {
#                     "type": "bar",
#                     "name": "\uc601\uc5b4",
#                     "legendHoverLink": true,
#                     "data": [
#                         72,
#                         91,
#                         78,
#                         93
#                     ],
#                     "showBackground": false,
#                     "stack": "2",
#                     "barMinHeight": 0,
#                     "barCategoryGap": "20%",
#                     "barGap": "30%",
#                     "large": false,
#                     "largeThreshold": 400,
#                     "seriesLayoutBy": "column",
#                     "datasetIndex": 0,
#                     "clip": true,
#                     "zlevel": 0,
#                     "z": 2,
#                     "label": {
#                         "show": false,
#                         "position": "top",
#                         "margin": 8
#                     },
#                     "rippleEffect": {
#                         "show": true,
#                         "brushType": "stroke",
#                         "scale": 2.5,
#                         "period": 4
#                     }
#                 }
#             ],
#             "xAxis": [
#                 {
#                     "type": "category",
#                     "name": "\uc774\ub984",
#                     "show": true,
#                     "scale": false,

# %% [markdown]
# 막대 그래프 외의 그래프를 pandasecharts로 그리고 싶다면 링크를 참조하라
#
# 링크 : https://caoqinping.com/2021/12/17/pandasecharts%E4%BD%BF%E7%94%A8%E7%A4%BA%E4%BE%8B/
